# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')

# %% [markdown]
# # 1. How big is the data?

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # 2. How does the data look like?

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.sample(5) #random, unlike head, so no bias
# Out:
#      PassengerId  Survived  Pclass  \
# 154          155         0       3
# 810          811         0       3
# 98            99         1       2
# 683          684         0       3
# 705          706         0       2
#
#                                                Name     Sex   Age  SibSp  \
# 154                           Olsen, Mr. Ole Martin    male   NaN      0
# 810                          Alexander, Mr. William    male  26.0      0
# 98             Doling, Mrs. John T (Ada Julia Bone)  female  34.0      0
# 683                     Goodwin, Mr. Charles Edward    male  14.0      5
# 705  Morley, Mr. Henry Samuel ("Mr Henry Marshall")    male  39.0      0
#
#      Parch     Ticket     Fare Cabin Embarked
# 154      0  Fa 265302   7.3125   NaN        S
# 810      0       3474   7.8875   NaN        S
# 98       1     231919  23.0000   NaN        S
# 683      2    CA 2144  46.9000   NaN        S
# 705      0     250655  26.0000   NaN        S

# %% [markdown]
# # 3. What is the data type of cols?

# %%
df.info() #maybe for a very large dataset you can reduce its space by changing some unneeded floats to ints (eg: age)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # 4. Are there any missing values?

# %%
#clearly we can see from prev cell that any col with less than 891 values is missing some values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # 5. How does the data look mathematically?

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # 6. Are there any duplicate values?

# %%
df.duplicated().sum() #shows no of duplicate rows which can be dropped using dropduplicate fxn of pandas
# Out:
# np.int64(0)

# %% [markdown]
# # 7. How is the correlation between cols?

# %%
df.corr(numeric_only=True) #gives pearson correlation coeff bw diff cols but if there are
#non numeric cols, it gives error, hence we use numeric_only=True
#if +ve corr, directly proportional
#else inversely proportional
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df.corr(numeric_only=True)['Survived'] #we get some cool insights like:
 #+ve corr bw survived and fare implies that rich people
 #would have been first onto the survival rafts and hence higher rate of survival
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64
